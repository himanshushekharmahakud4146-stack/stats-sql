# %% [markdown]
# # Customer Intelligence & Business Decision Engine
#
# Version 1.0
#
# This notebook will contain the complete business analysis using SQL.
#
# Today's work focuses on project planning and repository setup.
#
# Business analysis will begin after the database schema and dataset are prepared.

# %% [markdown]
# ## Customers Table
#
# Created the first normalized table for the Customer Intelligence Engine project.
#
# Purpose:
# - Store customer information.
# - Remove duplicated customer details.
# - Enable joins with the Orders table.
#
# Status:
# ✅ Table created successfully.

# %% [markdown]
# # Customer Intelligence Engine
#
# ## Objective
#
# Analyze retail sales using PostgreSQL.
#
# ## SQL Skills Used
#
# - SELECT
# - WHERE
# - GROUP BY
# - ORDER BY
# - LIMIT
# - COUNT
# - SUM
# - AVG
# - DISTINCT
#
# ## Business Questions
#
# - Which category generates the highest sales?
# - Which region earns the most profit?
# - Who are the top customers?
# - Which products perform best?
# - What is the average discount?
#
# ## Key Learning
#
# SQL is a powerful tool for transforming raw data into business insights.

# %%
# Business Analysis Notebook

print("Customer Intelligence Engine")
print("Day 30 Completed")
print("SQL Business Analysis Project")
# Out:
# Customer Intelligence Engine
# Day 30 Completed
# SQL Business Analysis Project
