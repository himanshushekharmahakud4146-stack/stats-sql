# %% [markdown]
# # SQL Problem Solving Analysis (HackerRank)
#
# ## Objective
#
# Strengthen SQL problem-solving skills by solving HackerRank SQL challenges independently and understanding how English requirements translate into SQL queries.
#
# ---
#
# # Platform
#
# - HackerRank
# - SQL
# - Basic Select
# - Advanced Select
#
# ---
#
# # Topics Practiced
#
# ## Basic Filtering
#
# - SELECT
# - WHERE
# - DISTINCT
# - AND
# - OR
#
# ---
#
# ## Pattern Matching
#
# - LIKE
# - NOT LIKE
# - Wildcards (%)
#
# Examples
#
# - Starts with vowel
# - Ends with vowel
# - Starts and ends with vowel
# - Does not start with vowel
# - Does not end with vowel
#
# ---
#
# ## String Functions
#
# - LEFT()
# - RIGHT()
# - CONCAT()
# - LOWER()
#
# ---
#
# ## Aggregation
#
# - COUNT()
# - COUNT(DISTINCT)
#
# ---
#
# ## Sorting
#
# - ORDER BY
# - Multi-column ORDER BY
#
# ---
#
# ## SQL Problems Solved
#
# - Revising the Select Query I
# - Revising the Select Query II
# - Select All
# - Select By ID
# - Japanese Cities
# - Weather Observation Station Series
# - Employee Names
# - Employee Salaries
# - The PADS
#
# ---
#
# # Key Learning
#
# Today I learned that solving SQL interview questions is not about memorizing syntax. The most important step is reading the question carefully, identifying the required output, and selecting the correct SQL clauses before writing the query.
#
# ---
#
# # Outcome
#
# - Improved SQL reasoning
# - Practiced interview-style questions
# - Built confidence in writing SQL without copying solutions
# - Strengthened understanding of filtering, sorting, aggregation, and string functions
