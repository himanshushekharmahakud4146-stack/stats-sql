# %% [markdown]
# # SQL Query Fundamentals
#
# ## Objective
#
# Learn the basic SQL commands used to retrieve, filter, sort, and limit data.
#
# ## Concepts Covered
#
# * SELECT
# * WHERE
# * ORDER BY
# * LIMIT
#
# ## Dataset
#
# sales table
#
# ## Key Learning
#
# SQL is used to retrieve information from databases. These four commands form the foundation of most SQL queries.
