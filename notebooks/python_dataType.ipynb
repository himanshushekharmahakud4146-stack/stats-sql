# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(0)
# Out:
# int

# %%
number = [1, 2, 3, 4, 5]
print(sum(number)/len(number))
type(sum(number)/len(number))
# Out:
# 3.0
# float

# %%
3/5
# Out:
# 0.6

# %%
6 * 10 ** (-1)
# Out:
# 0.6000000000000001

# %%
type(3/5)
# Out:
# float

# %%
type(math.pi)
# Out:
# float

# %%
type(10.0)
# Out:
# float

# %%
numbers = [math.pi, 10.0, 3/5]
(sum(numbers)/len(numbers))
# Out:
# 4.580530884529931

# %%
type(True)
# Out:
# bool

# %%
if 4 > 3:
    print("4 is greater than 3")
# Out:
# 4 is greater than 3

# %%
myList = [ True, 5 > 3, 1 == 5 , None is None]
for element in myList:
    print(type(element))
# Out:
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>

# %%
type ('Hello World')
# Out:
# str

# %%
type(math.pi)
# Out:
# float

# %%
type(None)
# Out:
# NoneType

# %%
myList = [1,1.1 ,'this is a sentence',None]
for element in myList:
    print(type(element))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'NoneType'>

# %%
myList = ['callable', 'argument', 'keyword argument', 'default parameter', 'variable length argument']
myList[3]
# Out:
# 'default parameter'

# %%
myList.sort()
myList
# Out:
# ['argument',
#  'callable',
#  'default parameter',
#  'keyword argument',
#  'variable length argument']
