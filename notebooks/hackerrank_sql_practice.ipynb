# %% [markdown]
# # HackerRank SQL Practice - Basic Select
#
# ## Objective
#
# The objective of this notebook is to improve SQL problem-solving skills by solving interview-style SQL questions on HackerRank. These exercises strengthen understanding of SQL syntax, filtering, aggregation, and string functions while preparing for technical interviews.
#
# ---
#
# # Platform
#
# - HackerRank
# - SQL Track
# - Basic Select
#
# ---
#
# # Problems Solved
#
# ## 1. Revising the Select Query I
#
# **Concepts Used**
#
# - SELECT
# - WHERE
# - AND
#
# **Learning**
#
# Filtered rows based on multiple conditions.
#
# ---
#
# ## 2. Revising the Select Query II
#
# **Concepts Used**
#
# - SELECT
# - WHERE
#
# **Learning**
#
# Selected only the required column instead of all columns.
#
# ---
#
# ## 3. Select All
#
# **Concepts Used**
#
# - SELECT *
#
# **Learning**
#
# Retrieved every row and every column from a table.
#
# ---
#
# ## 4. Select By ID
#
# **Concepts Used**
#
# - WHERE
#
# **Learning**
#
# Filtered records using a unique identifier.
#
# ---
#
# ## 5. Japanese Cities' Attributes
#
# **Concepts Used**
#
# - WHERE
# - COUNTRYCODE
#
# ---
#
# ## 6. Japanese Cities' Names
#
# **Concepts Used**
#
# - SELECT
# - WHERE
#
# ---
#
# ## 7. Weather Observation Station 1
#
# **Concepts Used**
#
# - Multiple column selection
#
# ---
#
# ## 8. Weather Observation Station 3
#
# **Concepts Used**
#
# - DISTINCT
# - MOD()
#
# **Learning**
#
# Learned to remove duplicate records while filtering even IDs.
#
# ---
#
# ## 9. Revising Aggregation
#
# **Concepts Used**
#
# - COUNT()
# - COUNT(DISTINCT)
#
# **Learning**
#
# Compared total records with unique records.
#
# ---
#
# # Skills Practiced
#
# - SELECT
# - WHERE
# - AND
# - DISTINCT
# - COUNT()
# - COUNT(DISTINCT)
# - MOD()
# - Filtering
# - Reading SQL questions
# - Writing interview-style SQL
#
# ---
#
# # Learning Outcome
#
# Today's practice improved my ability to understand SQL problem statements and convert business requirements into SQL queries. I also strengthened my confidence in solving beginner SQL interview questions independently.
