# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/student_performance.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (24, 10)

# %%
df.head()
# Out:
#    Student_ID  Age  Study_Hours  Attendance_Percent  Assignments_Completed  \
# 0           1   18            2                  78                      8
# 1           2   19            3                  82                      9
# 2           3   20            4                  85                     10
# 3           4   18            1                  70                      6
# 4           5   21            5                  90                     10
#
#    Quiz_Score  Midterm_Score  Final_Score  Projects_Completed  \
# 0          65             68           70                   1
# 1          70             72           74                   2
# 2          75             78           80                   2
# 3          60             62           65                   1
# 4          82             85           88                   3
#
#    Overall_Percentage
# 0                  68
# 1                  72
# 2                  78
# 3                  63
# 4                  85

# %%
df
# Out:
#     Student_ID  Age  Study_Hours  Attendance_Percent  Assignments_Completed  \
# 0            1   18            2                  78                      8
# 1            2   19            3                  82                      9
# 2            3   20            4                  85                     10
# 3            4   18            1                  70                      6
# 4            5   21            5                  90                     10
# 5            6   19            2                  76                      7
# 6            7   20            4                  88                      9
# 7            8   22            6                  95                     10
# 8            9   18            3                  80                      8
# 9           10   21            5                  91                     10
# 10          11   19            2                  77                      7
# ...

# %%
df["Final_Score"].mean()
# Out:
# np.float64(79.08333333333333)

# %%
df["Final_Score"].var()
# Out:
# 103.38405797101449

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Study_Hours', 'Attendance_Percent',
#        'Assignments_Completed', 'Quiz_Score', 'Midterm_Score', 'Final_Score',
#        'Projects_Completed', 'Overall_Percentage'],
#       dtype='object')

# %%
df.loc[:, 'Age']
# Out:
# 0     18
# 1     19
# 2     20
# 3     18
# 4     21
# 5     19
# 6     20
# 7     22
# 8     18
# 9     21
# 10    19
# 11    20
# 12    18
# 13    22
# 14    21
# 15    19
# 16    20
# 17    18
# 18    22
# 19    21
# 20    19
# 21    20
# 22    18
# 23    22
# Name: Age, dtype: int64

# %%
df.loc[:, ['Age', 'Study_Hours', 'Attendance_Percent']]
# Out:
#     Age  Study_Hours  Attendance_Percent
# 0    18            2                  78
# 1    19            3                  82
# 2    20            4                  85
# 3    18            1                  70
# 4    21            5                  90
# 5    19            2                  76
# 6    20            4                  88
# 7    22            6                  95
# 8    18            3                  80
# 9    21            5                  91
# 10   19            2                  77
# 11   20            4                  86
# 12   18            1                  72
# 13   22            6                  96
# 14   21            5                  89
# 15   19            3                  81
# 16   20            4                  84
# 17   18            2                  75
# 18   22            6                  94
# 19   21            5                  92
# 20   19            3                  79
# 21   20            4                  87
# ...

# %%
df.loc[:8, ['Age', 'Study_Hours', 'Attendance_Percent']]
# Out:
#    Age  Study_Hours  Attendance_Percent
# 0   18            2                  78
# 1   19            3                  82
# 2   20            4                  85
# 3   18            1                  70
# 4   21            5                  90
# 5   19            2                  76
# 6   20            4                  88
# 7   22            6                  95
# 8   18            3                  80

# %%
df.loc[9:16]
# Out:
#     Student_ID  Age  Study_Hours  Attendance_Percent  Assignments_Completed  \
# 9           10   21            5                  91                     10
# 10          11   19            2                  77                      7
# 11          12   20            4                  86                      9
# 12          13   18            1                  72                      6
# 13          14   22            6                  96                     10
# 14          15   21            5                  89                     10
# 15          16   19            3                  81                      8
# 16          17   20            4                  84                      9
#
#     Quiz_Score  Midterm_Score  Final_Score  Projects_Completed  \
# 9           84             86           89                   3
# 10          66             68           71                   1
# 11          76             79           81                   2
# ...

# %%
df.iloc[:4]
# Out:
#    Student_ID  Age  Study_Hours  Attendance_Percent  Assignments_Completed  \
# 0           1   18            2                  78                      8
# 1           2   19            3                  82                      9
# 2           3   20            4                  85                     10
# 3           4   18            1                  70                      6
#
#    Quiz_Score  Midterm_Score  Final_Score  Projects_Completed  \
# 0          65             68           70                   1
# 1          70             72           74                   2
# 2          75             78           80                   2
# 3          60             62           65                   1
#
#    Overall_Percentage
# 0                  68
# 1                  72
# 2                  78
# 3                  63

# %%
df.iloc[1:5,7:10]
# Out:
#    Final_Score  Projects_Completed  Overall_Percentage
# 1           74                   2                  72
# 2           80                   2                  78
# 3           65                   1                  63
# 4           88                   3                  85

# %%
df.iloc[1:5]
# Out:
#    Student_ID  Age  Study_Hours  Attendance_Percent  Assignments_Completed  \
# 1           2   19            3                  82                      9
# 2           3   20            4                  85                     10
# 3           4   18            1                  70                      6
# 4           5   21            5                  90                     10
#
#    Quiz_Score  Midterm_Score  Final_Score  Projects_Completed  \
# 1          70             72           74                   2
# 2          75             78           80                   2
# 3          60             62           65                   1
# 4          82             85           88                   3
#
#    Overall_Percentage
# 1                  72
# 2                  78
# 3                  63
# 4                  85

# %%
df.dtypes
# Out:
# Student_ID               int64
# Age                      int64
# Study_Hours              int64
# Attendance_Percent       int64
# Assignments_Completed    int64
# Quiz_Score               int64
# Midterm_Score            int64
# Final_Score              int64
# Projects_Completed       int64
# Overall_Percentage       int64
# dtype: object

# %%
df.Projects_Completed.unique()
# Out:
# array([1, 2, 3])

# %%
df.loc[:,["Student_ID","Age","Study_Hours" ]]
# Out:
#     Student_ID  Age  Study_Hours
# 0            1   18            2
# 1            2   19            3
# 2            3   20            4
# 3            4   18            1
# 4            5   21            5
# 5            6   19            2
# 6            7   20            4
# 7            8   22            6
# 8            9   18            3
# 9           10   21            5
# 10          11   19            2
# 11          12   20            4
# 12          13   18            1
# 13          14   22            6
# 14          15   21            5
# 15          16   19            3
# 16          17   20            4
# 17          18   18            2
# 18          19   22            6
# 19          20   21            5
# 20          21   19            3
# 21          22   20            4
# 22          23   18            2
# 23          24   22            6
