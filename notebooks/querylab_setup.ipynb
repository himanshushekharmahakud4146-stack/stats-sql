# %% [markdown]
# # PostgreSQL Setup and Python Connection
#
# ## Objective
#
# Connect Python with PostgreSQL using SQLAlchemy.
#
# ## Concepts Covered
#
# - PostgreSQL
# - Database
# - SQLAlchemy
# - psycopg2
# - SQL Queries
#
# ## Month 4 Day 14

# %%
import pandas as pd

from sqlalchemy import create_engine

# %%
engine = create_engine(
    "postgresql://localhost/querylab"
)

print("Connected Successfully")
# Out:
# Connected Successfully

# %% [markdown]
# # Summary
#
# In this notebook, PostgreSQL was successfully installed and configured on macOS. A database named `querylab` was created and tested using SQL commands. Python libraries `SQLAlchemy` and `psycopg2` were installed to enable communication between Python and PostgreSQL. This setup forms the foundation for future SQL practice, database management, and data analysis projects.
