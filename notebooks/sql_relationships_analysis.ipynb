# %% [markdown]
# # SQL Relationships, Joins & CASE Analysis (PostgreSQL)
#
# ## Objective
#
# Build relational databases using PostgreSQL and understand how multiple tables communicate using Primary Keys, Foreign Keys, and SQL Joins.
#
# ---
#
# # Databases Built
#
# - Product Database
# - Student Database
#
# ---
#
# # Topics Covered
#
# ## Database Design
#
# - CREATE DATABASE
# - CREATE TABLE
# - PRIMARY KEY
# - FOREIGN KEY
# - REFERENCES
# - ALTER TABLE
#
# ---
#
# ## Relationships
#
# ### One-to-Many Relationship
#
# A single product can appear in multiple customer orders.
#
# Example:
#
# products
#
# ↓
#
# orders
#
# The `product_id` acts as the foreign key.
#
# ---
#
# ## Student Relationship
#
# students
#
# ↓
#
# student_profile
#
# ↓
#
# marks
#
# One student can have multiple subject records.
#
# ---
#
# # SQL Joins
#
# ## INNER JOIN
#
# Returns matching records from both tables.
#
# ```sql
# SELECT *
# FROM products p
# JOIN orders o
# ON p.product_id = o.product_id;
# ```
#
# ---
#
# ## LEFT JOIN
#
# Returns every record from the left table and matching rows from the right table.
#
# ```sql
# SELECT *
# FROM products p
# LEFT JOIN orders o
# ON p.product_id=o.product_id;
# ```
#
# ---
#
# # GROUP BY
#
# Groups records before aggregation.
#
# ```sql
# SELECT product_name,
# COUNT(order_id)
# FROM products p
# LEFT JOIN orders o
# ON p.product_id=o.product_id
# GROUP BY product_name;
# ```
#
# ---
#
# # HAVING
#
# Filters grouped results.
#
# ```sql
# SELECT product_name,
# SUM(quantity*price)
# FROM products p
# JOIN orders o
# ON p.product_id=o.product_id
# GROUP BY product_name
# HAVING SUM(quantity*price)>2000;
# ```
#
# ---
#
# # CASE WHEN
#
# Used to categorize products.
#
# ```sql
# CASE
# WHEN price>1000 THEN 'Expensive'
# WHEN price BETWEEN 500 AND 1000 THEN 'Moderate'
# ELSE 'Cheap'
# END
# ```
#
# ---
#
# # Learning Summary
#
# Today I learned how real-world databases are connected using relationships. I practiced joining multiple tables, writing business queries, calculating revenue, and categorizing products using CASE WHEN. These concepts are essential for Data Analytics, Machine Learning data preparation, and SQL interviews.
